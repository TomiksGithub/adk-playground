# %%
# @title Step 0: Setup and Installation
import sys
# !{sys.executable} -m pip install google-adk
# !{sys.executable} -m pip install litellm
# !{sys.executable} -m pip install "google-adk[extensions]"

print("Installation complete.")
# Out:
# Requirement already satisfied: google-adk in .\.venv\Lib\site-packages (1.27.1)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in .\.venv\Lib\site-packages (from google-adk) (6.0.3)
# Requirement already satisfied: aiosqlite>=0.21.0 in .\.venv\Lib\site-packages (from google-adk) (0.22.1)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in .\.venv\Lib\site-packages (from google-adk) (4.12.1)
# Requirement already satisfied: authlib<2.0.0,>=1.6.6 in .\.venv\Lib\site-packages (from google-adk) (1.6.9)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in .\.venv\Lib\site-packages (from google-adk) (8.3.1)
# Requirement already satisfied: fastapi<1.0.0,>=0.124.1 in .\.venv\Lib\site-packages (from google-adk) (0.135.1)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in .\.venv\Lib\site-packages (from google-adk) (2.192.0)
# Requirement already satisfied: google-auth>=2.47.0 in .\.venv\Lib\site-packages (from google-auth[pyopenssl]>=2.47.0->google-adk) (2.49.1)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.132.0 in .\.venv\Lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (1.141.0)
# Requirement already satisfied: google-cloud-bigquery-storage>=2.0.0 in .\.venv\Lib\site-packages (from google-adk) (2.36.2)
# Requirement already satisfied: google-cloud-bigquery>=2.2.0 in .\.venv\Lib\site-packages (from google-adk) (3.40.1)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in .\.venv\Lib\site-packages (from google-adk) (2.35.0)
# Requirement already satisfied: google-cloud-dataplex<3.0.0,>=1.7.0 in .\.venv\Lib\site-packages (from google-adk) (2.16.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in .\.venv\Lib\site-packages (from google-adk) (0.13.12)
# Requirement already satisfied: google-cloud-pubsub<3.0.0,>=2.0.0 in .\.venv\Lib\site-packages (from google-adk) (2.36.0)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in .\.venv\Lib\site-packages (from google-adk) (2.26.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in .\.venv\Lib\site-packages (from google-adk) (3.63.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in .\.venv\Lib\site-packages (from google-adk) (2.37.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=2.18.0 in .\.venv\Lib\site-packages (from google-adk) (3.9.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.56.0 in .\.venv\Lib\site-packages (from google-adk) (1.67.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in .\.venv\Lib\site-packages (from google-adk) (0.21)
# Requirement already satisfied: httpx<1.0.0,>=0.27.0 in .\.venv\Lib\site-packages (from google-adk) (0.28.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in .\.venv\Lib\site-packages (from google-adk) (4.26.0)
# Requirement already satisfied: mcp<2.0.0,>=1.23.0 in .\.venv\Lib\site-packages (from google-adk) (1.26.0)
# Requirement already satisfied: opentelemetry-api<1.39.0,>=1.36.0 in .\.venv\Lib\site-packages (from google-adk) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in .\.venv\Lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in .\.venv\Lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in .\.venv\Lib\site-packages (from google-adk) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in .\.venv\Lib\site-packages (from google-adk) (1.38.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in .\.venv\Lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<1.39.0,>=1.36.0 in .\.venv\Lib\site-packages (from google-adk) (1.38.0)
# Requirement already satisfied: pyarrow>=14.0.0 in .\.venv\Lib\site-packages (from google-adk) (23.0.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.0 in .\.venv\Lib\site-packages (from google-adk) (2.12.5)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in .\.venv\Lib\site-packages (from google-adk) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in .\.venv\Lib\site-packages (from google-adk) (1.2.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in .\.venv\Lib\site-packages (from google-adk) (2.32.5)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in .\.venv\Lib\site-packages (from google-adk) (1.17.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in .\.venv\Lib\site-packages (from google-adk) (2.0.48)
# Requirement already satisfied: starlette<1.0.0,>=0.49.1 in .\.venv\Lib\site-packages (from google-adk) (0.52.1)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in .\.venv\Lib\site-packages (from google-adk) (9.1.4)
# Requirement already satisfied: typing-extensions<5,>=4.5 in .\.venv\Lib\site-packages (from google-adk) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in .\.venv\Lib\site-packages (from google-adk) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in .\.venv\Lib\site-packages (from google-adk) (0.41.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in .\.venv\Lib\site-packages (from google-adk) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in .\.venv\Lib\site-packages (from google-adk) (15.0.1)
# Requirement already satisfied: idna>=2.8 in .\.venv\Lib\site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (3.11)
# Requirement already satisfied: cryptography in .\.venv\Lib\site-packages (from authlib<2.0.0,>=1.6.6->google-adk) (46.0.5)
# Requirement already satisfied: colorama in .\.venv\Lib\site-packages (from click<9.0.0,>=8.1.8->google-adk) (0.4.6)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\.venv\Lib\site-packages (from fastapi<1.0.0,>=0.124.1->google-adk) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in .\.venv\Lib\site-packages (from fastapi<1.0.0,>=0.124.1->google-adk) (0.0.4)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in .\.venv\Lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.31.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in .\.venv\Lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in .\.venv\Lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.30.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in .\.venv\Lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in .\.venv\Lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.73.0)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.8 in .\.venv\Lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.33.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in .\.venv\Lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.27.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in .\.venv\Lib\site-packages (from google-auth>=2.47.0->google-auth[pyopenssl]>=2.47.0->google-adk) (0.4.2)
# Requirement already satisfied: packaging>=14.3 in .\.venv\Lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (26.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in .\.venv\Lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (1.16.0)
# Requirement already satisfied: docstring_parser<1 in .\.venv\Lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (0.17.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in .\.venv\Lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (1.78.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in .\.venv\Lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (1.78.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in .\.venv\Lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in .\.venv\Lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (1.18.0)
# Requirement already satisfied: google-cloud-logging<4 in .\.venv\Lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (3.14.0)
# Requirement already satisfied: google-cloud-iam in .\.venv\Lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (2.21.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in .\.venv\Lib\site-packages (from google-cloud-bigquery>=2.2.0->google-adk) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in .\.venv\Lib\site-packages (from google-cloud-bigquery>=2.2.0->google-adk) (2.8.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in .\.venv\Lib\site-packages (from google-cloud-dataplex<3.0.0,>=1.7.0->google-adk) (0.14.3)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in .\.venv\Lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (1.8.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in .\.venv\Lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk) (0.4.0)
# Requirement already satisfied: sqlparse>=0.4.4 in .\.venv\Lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.5.5)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in .\.venv\Lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.15.4)
# Requirement already satisfied: opentelemetry-semantic-conventions>=0.43b0 in .\.venv\Lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.59b0)
# Requirement already satisfied: google-cloud-monitoring>=2.16.0 in .\.venv\Lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (2.29.1)
# Requirement already satisfied: mmh3>=4.1.0 in .\.venv\Lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (5.2.1)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in .\.venv\Lib\site-packages (from google-cloud-storage<4.0.0,>=2.18.0->google-adk) (1.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in .\.venv\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->google-adk) (1.9.0)
# Requirement already satisfied: sniffio in .\.venv\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->google-adk) (1.3.1)
# Requirement already satisfied: pyparsing<4,>=3.1 in .\.venv\Lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (3.3.2)
# Requirement already satisfied: certifi in .\.venv\Lib\site-packages (from httpx<1.0.0,>=0.27.0->google-adk) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in .\.venv\Lib\site-packages (from httpx<1.0.0,>=0.27.0->google-adk) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\.venv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.27.0->google-adk) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in .\.venv\Lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\.venv\Lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in .\.venv\Lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in .\.venv\Lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (0.30.0)
# Requirement already satisfied: httpx-sse>=0.4 in .\.venv\Lib\site-packages (from mcp<2.0.0,>=1.23.0->google-adk) (0.4.3)
# Requirement already satisfied: pydantic-settings>=2.5.2 in .\.venv\Lib\site-packages (from mcp<2.0.0,>=1.23.0->google-adk) (2.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in .\.venv\Lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->google-adk) (2.12.1)
# Requirement already satisfied: python-multipart>=0.0.9 in .\.venv\Lib\site-packages (from mcp<2.0.0,>=1.23.0->google-adk) (0.0.22)
# Requirement already satisfied: pywin32>=310 in .\.venv\Lib\site-packages (from mcp<2.0.0,>=1.23.0->google-adk) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in .\.venv\Lib\site-packages (from mcp<2.0.0,>=1.23.0->google-adk) (3.3.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in .\.venv\Lib\site-packages (from opentelemetry-api<1.39.0,>=1.36.0->google-adk) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in .\.venv\Lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<1.39.0,>=1.36.0->google-adk) (3.23.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in .\.venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in .\.venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.38.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.12.0->google-adk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.12.0->google-adk) (2.41.5)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests<3.0.0,>=2.32.4->google-adk) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\.venv\Lib\site-packages (from requests<3.0.0,>=2.32.4->google-adk) (2.6.3)
# Requirement already satisfied: greenlet>=1 in .\.venv\Lib\site-packages (from sqlalchemy<3.0.0,>=2.0->google-adk) (3.3.2)
# Requirement already satisfied: tzdata in .\.venv\Lib\site-packages (from tzlocal<6.0,>=5.3->google-adk) (2025.3)
# Requirement already satisfied: cffi>=2.0.0 in .\.venv\Lib\site-packages (from cryptography->authlib<2.0.0,>=1.6.6->google-adk) (2.0.0)
# Requirement already satisfied: pycparser in .\.venv\Lib\site-packages (from cffi>=2.0.0->cryptography->authlib<2.0.0,>=1.6.6->google-adk) (3.0)
# Requirement already satisfied: pyopenssl>=20.0.0 in .\.venv\Lib\site-packages (from google-auth[pyopenssl]>=2.47.0->google-adk) (25.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in .\.venv\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.47.0->google-auth[pyopenssl]>=2.47.0->google-adk) (0.6.2)
# Requirement already satisfied: alembic in .\.venv\Lib\site-packages (from sqlalchemy-spanner>=1.14.0->google-adk) (1.18.4)
# Requirement already satisfied: Mako in .\.venv\Lib\site-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (1.3.10)
# Requirement already satisfied: MarkupSafe>=0.9.2 in .\.venv\Lib\site-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk) (3.0.3)
# Requirement already satisfied: litellm in .\.venv\Lib\site-packages (1.82.2)
# Requirement already satisfied: aiohttp>=3.10 in .\.venv\Lib\site-packages (from litellm) (3.13.3)
# Requirement already satisfied: click in .\.venv\Lib\site-packages (from litellm) (8.3.1)
# Requirement already satisfied: fastuuid>=0.13.0 in .\.venv\Lib\site-packages (from litellm) (0.14.0)
# Requirement already satisfied: httpx>=0.23.0 in .\.venv\Lib\site-packages (from litellm) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in .\.venv\Lib\site-packages (from litellm) (8.7.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in .\.venv\Lib\site-packages (from litellm) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in .\.venv\Lib\site-packages (from litellm) (4.26.0)
# Requirement already satisfied: openai>=2.8.0 in .\.venv\Lib\site-packages (from litellm) (2.28.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.0 in .\.venv\Lib\site-packages (from litellm) (2.12.5)
# Requirement already satisfied: python-dotenv>=0.2.0 in .\.venv\Lib\site-packages (from litellm) (1.2.2)
# Requirement already satisfied: tiktoken>=0.7.0 in .\.venv\Lib\site-packages (from litellm) (0.12.0)
# Requirement already satisfied: tokenizers in .\.venv\Lib\site-packages (from litellm) (0.22.2)
# Requirement already satisfied: MarkupSafe>=2.0 in .\.venv\Lib\site-packages (from jinja2<4.0.0,>=3.1.2->litellm) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in .\.venv\Lib\site-packages (from jsonschema<5.0.0,>=4.23.0->litellm) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\.venv\Lib\site-packages (from jsonschema<5.0.0,>=4.23.0->litellm) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in .\.venv\Lib\site-packages (from jsonschema<5.0.0,>=4.23.0->litellm) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in .\.venv\Lib\site-packages (from jsonschema<5.0.0,>=4.23.0->litellm) (0.30.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.5.0->litellm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.5.0->litellm) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in .\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.5.0->litellm) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.5.0->litellm) (0.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in .\.venv\Lib\site-packages (from aiohttp>=3.10->litellm) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in .\.venv\Lib\site-packages (from aiohttp>=3.10->litellm) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in .\.venv\Lib\site-packages (from aiohttp>=3.10->litellm) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in .\.venv\Lib\site-packages (from aiohttp>=3.10->litellm) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in .\.venv\Lib\site-packages (from aiohttp>=3.10->litellm) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in .\.venv\Lib\site-packages (from aiohttp>=3.10->litellm) (1.23.0)
# Requirement already satisfied: idna>=2.0 in .\.venv\Lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.10->litellm) (3.11)
# Requirement already satisfied: anyio in .\.venv\Lib\site-packages (from httpx>=0.23.0->litellm) (4.12.1)
# Requirement already satisfied: certifi in .\.venv\Lib\site-packages (from httpx>=0.23.0->litellm) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in .\.venv\Lib\site-packages (from httpx>=0.23.0->litellm) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.23.0->litellm) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in .\.venv\Lib\site-packages (from importlib-metadata>=6.8.0->litellm) (3.23.0)
# Requirement already satisfied: distro<2,>=1.7.0 in .\.venv\Lib\site-packages (from openai>=2.8.0->litellm) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in .\.venv\Lib\site-packages (from openai>=2.8.0->litellm) (0.13.0)
# Requirement already satisfied: sniffio in .\.venv\Lib\site-packages (from openai>=2.8.0->litellm) (1.3.1)
# Requirement already satisfied: tqdm>4 in .\.venv\Lib\site-packages (from openai>=2.8.0->litellm) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in .\.venv\Lib\site-packages (from tiktoken>=0.7.0->litellm) (2026.2.28)
# Requirement already satisfied: requests>=2.26.0 in .\.venv\Lib\site-packages (from tiktoken>=0.7.0->litellm) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\.venv\Lib\site-packages (from requests>=2.26.0->tiktoken>=0.7.0->litellm) (2.6.3)
# Requirement already satisfied: colorama in .\.venv\Lib\site-packages (from tqdm>4->openai>=2.8.0->litellm) (0.4.6)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in .\.venv\Lib\site-packages (from tokenizers->litellm) (1.7.1)
# Requirement already satisfied: filelock>=3.10.0 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (1.4.2)
# Requirement already satisfied: packaging>=20.9 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (6.0.3)
# Requirement already satisfied: typer in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (0.24.1)
# Requirement already satisfied: shellingham>=1.3.0 in .\.venv\Lib\site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in .\.venv\Lib\site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in .\.venv\Lib\site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\.venv\Lib\site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\.venv\Lib\site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in .\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm) (0.1.2)
# Requirement already satisfied: google-adk[extensions] in .\.venv\Lib\site-packages (1.27.1)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in .\.venv\Lib\site-packages (from google-adk[extensions]) (6.0.3)
# Requirement already satisfied: aiosqlite>=0.21.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (0.22.1)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (4.12.1)
# Requirement already satisfied: authlib<2.0.0,>=1.6.6 in .\.venv\Lib\site-packages (from google-adk[extensions]) (1.6.9)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in .\.venv\Lib\site-packages (from google-adk[extensions]) (8.3.1)
# Requirement already satisfied: fastapi<1.0.0,>=0.124.1 in .\.venv\Lib\site-packages (from google-adk[extensions]) (0.135.1)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (2.192.0)
# Requirement already satisfied: google-auth>=2.47.0 in .\.venv\Lib\site-packages (from google-auth[pyopenssl]>=2.47.0->google-adk[extensions]) (2.49.1)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.132.0 in .\.venv\Lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (1.141.0)
# Requirement already satisfied: google-cloud-bigquery-storage>=2.0.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (2.36.2)
# Requirement already satisfied: google-cloud-bigquery>=2.2.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (3.40.1)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (2.35.0)
# Requirement already satisfied: google-cloud-dataplex<3.0.0,>=1.7.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (2.16.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in .\.venv\Lib\site-packages (from google-adk[extensions]) (0.13.12)
# Requirement already satisfied: google-cloud-pubsub<3.0.0,>=2.0.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (2.36.0)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (2.26.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (3.63.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (2.37.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=2.18.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (3.9.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.56.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (1.67.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in .\.venv\Lib\site-packages (from google-adk[extensions]) (0.21)
# Requirement already satisfied: httpx<1.0.0,>=0.27.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (0.28.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (4.26.0)
# Requirement already satisfied: mcp<2.0.0,>=1.23.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (1.26.0)
# Requirement already satisfied: opentelemetry-api<1.39.0,>=1.36.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (1.38.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<1.39.0,>=1.36.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (1.38.0)
# Requirement already satisfied: pyarrow>=14.0.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (23.0.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (2.12.5)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (1.2.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in .\.venv\Lib\site-packages (from google-adk[extensions]) (2.32.5)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (1.17.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (2.0.48)
# Requirement already satisfied: starlette<1.0.0,>=0.49.1 in .\.venv\Lib\site-packages (from google-adk[extensions]) (0.52.1)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (9.1.4)
# Requirement already satisfied: typing-extensions<5,>=4.5 in .\.venv\Lib\site-packages (from google-adk[extensions]) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in .\.venv\Lib\site-packages (from google-adk[extensions]) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (0.41.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in .\.venv\Lib\site-packages (from google-adk[extensions]) (15.0.1)
# Requirement already satisfied: anthropic>=0.43.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (0.84.0)
# Requirement already satisfied: beautifulsoup4>=3.2.2 in .\.venv\Lib\site-packages (from google-adk[extensions]) (4.14.3)
# Requirement already satisfied: docker>=7.0.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (7.1.0)
# Requirement already satisfied: kubernetes>=29.0.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (35.0.0)
# Requirement already satisfied: k8s-agent-sandbox>=0.1.1.post2 in .\.venv\Lib\site-packages (from google-adk[extensions]) (0.2.1)
# Requirement already satisfied: langgraph<0.4.8,>=0.2.60 in .\.venv\Lib\site-packages (from google-adk[extensions]) (0.4.7)
# Requirement already satisfied: litellm<2.0.0,>=1.75.5 in .\.venv\Lib\site-packages (from google-adk[extensions]) (1.82.2)
# Requirement already satisfied: llama-index-readers-file>=0.4.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (0.6.0)
# Requirement already satisfied: llama-index-embeddings-google-genai>=0.3.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (0.5.0)
# Requirement already satisfied: lxml>=5.3.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (6.0.2)
# Requirement already satisfied: pypika>=0.50.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (0.51.1)
# Requirement already satisfied: toolbox-adk<0.8.0,>=0.7.0 in .\.venv\Lib\site-packages (from google-adk[extensions]) (0.7.0)
# Requirement already satisfied: idna>=2.8 in .\.venv\Lib\site-packages (from anyio<5.0.0,>=4.9.0->google-adk[extensions]) (3.11)
# Requirement already satisfied: cryptography in .\.venv\Lib\site-packages (from authlib<2.0.0,>=1.6.6->google-adk[extensions]) (46.0.5)
# Requirement already satisfied: colorama in .\.venv\Lib\site-packages (from click<9.0.0,>=8.1.8->google-adk[extensions]) (0.4.6)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\.venv\Lib\site-packages (from fastapi<1.0.0,>=0.124.1->google-adk[extensions]) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in .\.venv\Lib\site-packages (from fastapi<1.0.0,>=0.124.1->google-adk[extensions]) (0.0.4)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in .\.venv\Lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk[extensions]) (0.31.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in .\.venv\Lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk[extensions]) (0.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in .\.venv\Lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk[extensions]) (2.30.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in .\.venv\Lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk[extensions]) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in .\.venv\Lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk[extensions]) (1.73.0)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.8 in .\.venv\Lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk[extensions]) (6.33.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in .\.venv\Lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk[extensions]) (1.27.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in .\.venv\Lib\site-packages (from google-auth>=2.47.0->google-auth[pyopenssl]>=2.47.0->google-adk[extensions]) (0.4.2)
# Requirement already satisfied: packaging>=14.3 in .\.venv\Lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (26.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in .\.venv\Lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (1.16.0)
# Requirement already satisfied: docstring_parser<1 in .\.venv\Lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (0.17.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in .\.venv\Lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (1.78.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in .\.venv\Lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.132.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (1.78.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in .\.venv\Lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in .\.venv\Lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (1.18.0)
# Requirement already satisfied: google-cloud-logging<4 in .\.venv\Lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (3.14.0)
# Requirement already satisfied: google-cloud-iam in .\.venv\Lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (2.21.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in .\.venv\Lib\site-packages (from google-cloud-bigquery>=2.2.0->google-adk[extensions]) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in .\.venv\Lib\site-packages (from google-cloud-bigquery>=2.2.0->google-adk[extensions]) (2.8.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in .\.venv\Lib\site-packages (from google-cloud-dataplex<3.0.0,>=1.7.0->google-adk[extensions]) (0.14.3)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in .\.venv\Lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (1.8.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in .\.venv\Lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.132.0->google-adk[extensions]) (0.4.0)
# Requirement already satisfied: sqlparse>=0.4.4 in .\.venv\Lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk[extensions]) (0.5.5)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in .\.venv\Lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk[extensions]) (0.15.4)
# Requirement already satisfied: opentelemetry-semantic-conventions>=0.43b0 in .\.venv\Lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk[extensions]) (0.59b0)
# Requirement already satisfied: google-cloud-monitoring>=2.16.0 in .\.venv\Lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk[extensions]) (2.29.1)
# Requirement already satisfied: mmh3>=4.1.0 in .\.venv\Lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk[extensions]) (5.2.1)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in .\.venv\Lib\site-packages (from google-cloud-storage<4.0.0,>=2.18.0->google-adk[extensions]) (1.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in .\.venv\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->google-adk[extensions]) (1.9.0)
# Requirement already satisfied: sniffio in .\.venv\Lib\site-packages (from google-genai<2.0.0,>=1.56.0->google-adk[extensions]) (1.3.1)
# Requirement already satisfied: pyparsing<4,>=3.1 in .\.venv\Lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk[extensions]) (3.3.2)
# Requirement already satisfied: certifi in .\.venv\Lib\site-packages (from httpx<1.0.0,>=0.27.0->google-adk[extensions]) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in .\.venv\Lib\site-packages (from httpx<1.0.0,>=0.27.0->google-adk[extensions]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\.venv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.27.0->google-adk[extensions]) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in .\.venv\Lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk[extensions]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\.venv\Lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk[extensions]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in .\.venv\Lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk[extensions]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in .\.venv\Lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk[extensions]) (0.30.0)
# Requirement already satisfied: langchain-core>=0.1 in .\.venv\Lib\site-packages (from langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (1.2.19)
# Requirement already satisfied: langgraph-checkpoint>=2.0.26 in .\.venv\Lib\site-packages (from langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt>=0.2.0 in .\.venv\Lib\site-packages (from langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (1.0.8)
# Requirement already satisfied: langgraph-sdk>=0.1.42 in .\.venv\Lib\site-packages (from langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (0.3.11)
# Requirement already satisfied: xxhash>=3.5.0 in .\.venv\Lib\site-packages (from langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (3.6.0)
# Requirement already satisfied: aiohttp>=3.10 in .\.venv\Lib\site-packages (from litellm<2.0.0,>=1.75.5->google-adk[extensions]) (3.13.3)
# Requirement already satisfied: fastuuid>=0.13.0 in .\.venv\Lib\site-packages (from litellm<2.0.0,>=1.75.5->google-adk[extensions]) (0.14.0)
# Requirement already satisfied: importlib-metadata>=6.8.0 in .\.venv\Lib\site-packages (from litellm<2.0.0,>=1.75.5->google-adk[extensions]) (8.7.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in .\.venv\Lib\site-packages (from litellm<2.0.0,>=1.75.5->google-adk[extensions]) (3.1.6)
# Requirement already satisfied: openai>=2.8.0 in .\.venv\Lib\site-packages (from litellm<2.0.0,>=1.75.5->google-adk[extensions]) (2.28.0)
# Requirement already satisfied: tiktoken>=0.7.0 in .\.venv\Lib\site-packages (from litellm<2.0.0,>=1.75.5->google-adk[extensions]) (0.12.0)
# Requirement already satisfied: tokenizers in .\.venv\Lib\site-packages (from litellm<2.0.0,>=1.75.5->google-adk[extensions]) (0.22.2)
# Requirement already satisfied: MarkupSafe>=2.0 in .\.venv\Lib\site-packages (from jinja2<4.0.0,>=3.1.2->litellm<2.0.0,>=1.75.5->google-adk[extensions]) (3.0.3)
# Requirement already satisfied: httpx-sse>=0.4 in .\.venv\Lib\site-packages (from mcp<2.0.0,>=1.23.0->google-adk[extensions]) (0.4.3)
# Requirement already satisfied: pydantic-settings>=2.5.2 in .\.venv\Lib\site-packages (from mcp<2.0.0,>=1.23.0->google-adk[extensions]) (2.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in .\.venv\Lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->google-adk[extensions]) (2.12.1)
# Requirement already satisfied: python-multipart>=0.0.9 in .\.venv\Lib\site-packages (from mcp<2.0.0,>=1.23.0->google-adk[extensions]) (0.0.22)
# Requirement already satisfied: pywin32>=310 in .\.venv\Lib\site-packages (from mcp<2.0.0,>=1.23.0->google-adk[extensions]) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in .\.venv\Lib\site-packages (from mcp<2.0.0,>=1.23.0->google-adk[extensions]) (3.3.2)
# Requirement already satisfied: zipp>=3.20 in .\.venv\Lib\site-packages (from importlib-metadata>=6.8.0->litellm<2.0.0,>=1.75.5->google-adk[extensions]) (3.23.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in .\.venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk[extensions]) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in .\.venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk[extensions]) (1.38.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.12.0->google-adk[extensions]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.12.0->google-adk[extensions]) (2.41.5)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk[extensions]) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests<3.0.0,>=2.32.4->google-adk[extensions]) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\.venv\Lib\site-packages (from requests<3.0.0,>=2.32.4->google-adk[extensions]) (2.6.3)
# Requirement already satisfied: greenlet>=1 in .\.venv\Lib\site-packages (from sqlalchemy<3.0.0,>=2.0->google-adk[extensions]) (3.3.2)
# Requirement already satisfied: toolbox-core==0.5.10 in .\.venv\Lib\site-packages (from toolbox-adk<0.8.0,>=0.7.0->google-adk[extensions]) (0.5.10)
# Requirement already satisfied: google-auth-oauthlib<2.0.0,>=1.2.0 in .\.venv\Lib\site-packages (from toolbox-adk<0.8.0,>=0.7.0->google-adk[extensions]) (1.3.0)
# Requirement already satisfied: deprecated<2.0.0,>=1.2.15 in .\.venv\Lib\site-packages (from toolbox-core==0.5.10->toolbox-adk<0.8.0,>=0.7.0->google-adk[extensions]) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in .\.venv\Lib\site-packages (from aiohttp>=3.10->litellm<2.0.0,>=1.75.5->google-adk[extensions]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in .\.venv\Lib\site-packages (from aiohttp>=3.10->litellm<2.0.0,>=1.75.5->google-adk[extensions]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in .\.venv\Lib\site-packages (from aiohttp>=3.10->litellm<2.0.0,>=1.75.5->google-adk[extensions]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in .\.venv\Lib\site-packages (from aiohttp>=3.10->litellm<2.0.0,>=1.75.5->google-adk[extensions]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in .\.venv\Lib\site-packages (from aiohttp>=3.10->litellm<2.0.0,>=1.75.5->google-adk[extensions]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in .\.venv\Lib\site-packages (from aiohttp>=3.10->litellm<2.0.0,>=1.75.5->google-adk[extensions]) (1.23.0)
# Requirement already satisfied: wrapt<3,>=1.10 in .\.venv\Lib\site-packages (from deprecated<2.0.0,>=1.2.15->toolbox-core==0.5.10->toolbox-adk<0.8.0,>=0.7.0->google-adk[extensions]) (2.1.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in .\.venv\Lib\site-packages (from google-auth-oauthlib<2.0.0,>=1.2.0->toolbox-adk<0.8.0,>=0.7.0->google-adk[extensions]) (2.0.0)
# Requirement already satisfied: tzdata in .\.venv\Lib\site-packages (from tzlocal<6.0,>=5.3->google-adk[extensions]) (2025.3)
# Requirement already satisfied: jiter<1,>=0.4.0 in .\.venv\Lib\site-packages (from anthropic>=0.43.0->google-adk[extensions]) (0.13.0)
# Requirement already satisfied: soupsieve>=1.6.1 in .\.venv\Lib\site-packages (from beautifulsoup4>=3.2.2->google-adk[extensions]) (2.8.3)
# Requirement already satisfied: cffi>=2.0.0 in .\.venv\Lib\site-packages (from cryptography->authlib<2.0.0,>=1.6.6->google-adk[extensions]) (2.0.0)
# Requirement already satisfied: pycparser in .\.venv\Lib\site-packages (from cffi>=2.0.0->cryptography->authlib<2.0.0,>=1.6.6->google-adk[extensions]) (3.0)
# Requirement already satisfied: pyopenssl>=20.0.0 in .\.venv\Lib\site-packages (from google-auth[pyopenssl]>=2.47.0->google-adk[extensions]) (25.3.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in .\.venv\Lib\site-packages (from kubernetes>=29.0.0->google-adk[extensions]) (1.9.0)
# Requirement already satisfied: durationpy>=0.7 in .\.venv\Lib\site-packages (from kubernetes>=29.0.0->google-adk[extensions]) (0.10)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in .\.venv\Lib\site-packages (from langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in .\.venv\Lib\site-packages (from langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (0.7.17)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in .\.venv\Lib\site-packages (from langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in .\.venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in .\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in .\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in .\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (0.25.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in .\.venv\Lib\site-packages (from langgraph-checkpoint>=2.0.26->langgraph<0.4.8,>=0.2.60->google-adk[extensions]) (1.12.2)
# Requirement already satisfied: llama-index-core<0.15,>=0.13.0 in .\.venv\Lib\site-packages (from llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (0.14.17)
# Requirement already satisfied: banks<3,>=2.3.0 in .\.venv\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (2.4.1)
# Requirement already satisfied: dataclasses-json in .\.venv\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (0.6.7)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in .\.venv\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in .\.venv\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in .\.venv\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (2026.2.0)
# Requirement already satisfied: llama-index-workflows!=2.9.0,<3,>=2 in .\.venv\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (2.16.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in .\.venv\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in .\.venv\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (3.6.1)
# Requirement already satisfied: nltk>3.8.1 in .\.venv\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (3.9.3)
# Requirement already satisfied: numpy in .\.venv\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (2.4.3)
# Requirement already satisfied: pillow>=9.0.0 in .\.venv\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (12.1.1)
# Requirement already satisfied: platformdirs in .\.venv\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (4.9.4)
# Requirement already satisfied: setuptools>=80.9.0 in .\.venv\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (82.0.1)
# Requirement already satisfied: tinytag>=2.2.0 in .\.venv\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (2.2.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in .\.venv\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (4.67.3)
# Requirement already satisfied: typing-inspect>=0.8.0 in .\.venv\Lib\site-packages (from llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (0.9.0)
# Requirement already satisfied: griffe in .\.venv\Lib\site-packages (from banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (2.0.0)
# Requirement already satisfied: llama-index-instrumentation>=0.4.3 in .\.venv\Lib\site-packages (from llama-index-workflows!=2.9.0,<3,>=2->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (0.5.0)
# Requirement already satisfied: defusedxml>=0.7.1 in .\.venv\Lib\site-packages (from llama-index-readers-file>=0.4.0->google-adk[extensions]) (0.7.1)
# Requirement already satisfied: pandas<3,>=2.0.0 in .\.venv\Lib\site-packages (from llama-index-readers-file>=0.4.0->google-adk[extensions]) (2.3.3)
# Requirement already satisfied: pypdf<7,>=6.1.3 in .\.venv\Lib\site-packages (from llama-index-readers-file>=0.4.0->google-adk[extensions]) (6.8.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in .\.venv\Lib\site-packages (from llama-index-readers-file>=0.4.0->google-adk[extensions]) (0.0.26)
# Requirement already satisfied: pytz>=2020.1 in .\.venv\Lib\site-packages (from pandas<3,>=2.0.0->llama-index-readers-file>=0.4.0->google-adk[extensions]) (2026.1.post1)
# Requirement already satisfied: joblib in .\.venv\Lib\site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in .\.venv\Lib\site-packages (from nltk>3.8.1->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (2026.2.28)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in .\.venv\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.47.0->google-auth[pyopenssl]>=2.47.0->google-adk[extensions]) (0.6.2)
# Requirement already satisfied: oauthlib>=3.0.0 in .\.venv\Lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2.0.0,>=1.2.0->toolbox-adk<0.8.0,>=0.7.0->google-adk[extensions]) (3.3.1)
# Requirement already satisfied: alembic in .\.venv\Lib\site-packages (from sqlalchemy-spanner>=1.14.0->google-adk[extensions]) (1.18.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in .\.venv\Lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (1.1.0)
# Requirement already satisfied: Mako in .\.venv\Lib\site-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk[extensions]) (1.3.10)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in .\.venv\Lib\site-packages (from dataclasses-json->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (3.26.2)
# Requirement already satisfied: griffecli==2.0.0 in .\.venv\Lib\site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (2.0.0)
# Requirement already satisfied: griffelib==2.0.0 in .\.venv\Lib\site-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15,>=0.13.0->llama-index-embeddings-google-genai>=0.3.0->google-adk[extensions]) (2.0.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in .\.venv\Lib\site-packages (from tokenizers->litellm<2.0.0,>=1.75.5->google-adk[extensions]) (1.7.1)
# Requirement already satisfied: filelock>=3.10.0 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.75.5->google-adk[extensions]) (3.25.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.75.5->google-adk[extensions]) (1.4.2)
# Requirement already satisfied: typer in .\.venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.75.5->google-adk[extensions]) (0.24.1)
# Requirement already satisfied: shellingham>=1.3.0 in .\.venv\Lib\site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.75.5->google-adk[extensions]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in .\.venv\Lib\site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.75.5->google-adk[extensions]) (14.3.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\.venv\Lib\site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.75.5->google-adk[extensions]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\.venv\Lib\site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.75.5->google-adk[extensions]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in .\.venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.75.5->google-adk[extensions]) (0.1.2)
# Installation complete.

# %%
# @title Import necessary libraries
import os
import asyncio
from google.adk.agents import Agent
from google.adk.models.lite_llm import LiteLlm # For multi-model support
from google.adk.sessions import InMemorySessionService
from google.adk.runners import Runner
from google.genai import types # For creating message Content/Parts

import warnings
# Ignore all warnings
warnings.filterwarnings("ignore")

import logging
logging.basicConfig(level=logging.ERROR)

print("Libraries imported.")
# Out:
# Libraries imported.

# %%
# @title Configure API Keys (loaded from .env file)
from dotenv import load_dotenv
load_dotenv(override=True)  # reads .env from project root

# Keys are now loaded automatically from .env file.
# Make sure .env contains:
#   GOOGLE_API_KEY=your_key
#   OPENAI_API_KEY=your_key       (optional)
#   ANTHROPIC_API_KEY=your_key    (optional)

# --- Verify Keys (Optional Check) ---
print("API Keys Set:")
print(f"Google API Key set: {'Yes' if os.environ.get('GOOGLE_API_KEY') and os.environ['GOOGLE_API_KEY'] != 'YOUR_GOOGLE_API_KEY' else 'No (REPLACE PLACEHOLDER!)'}")
print(f"OpenAI API Key set: {'Yes' if os.environ.get('OPENAI_API_KEY') and os.environ['OPENAI_API_KEY'] != 'YOUR_OPENAI_API_KEY' else 'No (REPLACE PLACEHOLDER!)'}")
print(f"Anthropic API Key set: {'Yes' if os.environ.get('ANTHROPIC_API_KEY') and os.environ['ANTHROPIC_API_KEY'] != 'YOUR_ANTHROPIC_API_KEY' else 'No (REPLACE PLACEHOLDER!)'}")

# Configure ADK to use API keys directly (not Vertex AI for this multi-model setup)
os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "False"


# @markdown **Security Note:** It's best practice to manage API keys securely (e.g., using Colab Secrets or environment variables) rather than hardcoding them directly in the notebook. Replace the placeholder strings above.
# Out:
# API Keys Set:
# Google API Key set: Yes
# OpenAI API Key set: Yes
# Anthropic API Key set: Yes

# %%
# --- Define Model Constants for easier use ---

# More supported models can be referenced here: https://ai.google.dev/gemini-api/docs/models#model-variations
MODEL_GEMINI_2_5_FLASH = "gemini-2.5-flash"

# More supported models can be referenced here: https://docs.litellm.ai/docs/providers/openai#openai-chat-completion-models
MODEL_GPT_4O = "openai/gpt-4.1" # You can also try: gpt-4.1-mini, gpt-4o etc.

# More supported models can be referenced here: https://docs.litellm.ai/docs/providers/anthropic
MODEL_CLAUDE_SONNET = "claude-sonnet-4-6" # You can also try: claude-opus-4-6, etc

print("\nEnvironment configured.")
# Out:
# Environment configured.

# %%
import sys
# !{sys.executable} -m pip install requests geopy timezonefinder pytz
print("Done.")
# Out:
# Requirement already satisfied: requests in .\.venv\Lib\site-packages (2.32.5)
# Requirement already satisfied: geopy in .\.venv\Lib\site-packages (2.4.1)
# Requirement already satisfied: timezonefinder in .\.venv\Lib\site-packages (8.2.1)
# Requirement already satisfied: pytz in .\.venv\Lib\site-packages (2026.1.post1)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in .\.venv\Lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\.venv\Lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in .\.venv\Lib\site-packages (from requests) (2026.2.25)
# Requirement already satisfied: geographiclib<3,>=1.52 in .\.venv\Lib\site-packages (from geopy) (2.1)
# Requirement already satisfied: numpy>=2 in .\.venv\Lib\site-packages (from timezonefinder) (2.4.3)
# Requirement already satisfied: h3>=4 in .\.venv\Lib\site-packages (from timezonefinder) (4.4.2)
# Requirement already satisfied: cffi<3,>=1.15.1 in .\.venv\Lib\site-packages (from timezonefinder) (2.0.0)
# Requirement already satisfied: flatbuffers>=25.2.10 in .\.venv\Lib\site-packages (from timezonefinder) (25.12.19)
# Requirement already satisfied: pycparser in .\.venv\Lib\site-packages (from cffi<3,>=1.15.1->timezonefinder) (3.0)
# Done.

# %%
import datetime
import requests
from geopy.geocoders import Nominatim
from timezonefinder import TimezoneFinder
import pytz
from google.adk.agents.llm_agent import Agent
from google.adk.models.google_llm import Gemini
from google.genai import types

def get_timezone(city: str) -> str | None:
    """Return the IANA timezone string for a given city, or None if not found."""
    geolocator = Nominatim(user_agent="city_time_agent")
    location = geolocator.geocode(city)
    if not location:
        return None
    tf = TimezoneFinder()
    return tf.timezone_at(lng=location.longitude, lat=location.latitude)


def get_current_time(city: str) -> dict:
    """Get current time in provided city."""
    try:
        timezone_str = get_timezone(city)
        if not timezone_str:
            return {"status": "error", "error": f"Could not determine timezone for city: {city}"}

        now = datetime.datetime.now(pytz.timezone(timezone_str))
        time_str = now.strftime('%I:%M %p')
        return {"status": "success", "city": city, "timea": time_str}
    except Exception as e:
        return {"status": "error", "error": str(e)}


def get_weather(city: str) -> dict:
    """Get current weather for a given city using the Open-Meteo API.

    Args:
        city: Name of the city, e.g. 'Warsaw', 'London'.

    Returns:
        dict: status and weather report or error message.
    """
    try:
        geolocator = Nominatim(user_agent="city_weather_agent")
        location = geolocator.geocode(city)
        if not location:
            return {"status": "error", "error": f"Could not find location for city: {city}"}

        url = (
            f"https://api.open-meteo.com/v1/forecast"
            f"?latitude={location.latitude}&longitude={location.longitude}"
            f"&current=temperature_2m,weathercode,windspeed_10m"
            f"&wind_speed_unit=ms"
        )
        response = requests.get(url, timeout=5)
        response.raise_for_status()
        data = response.json()["current"]

        return {
            "status": "success",
            "city": city,
            "temperature_c": data["temperature_2m"],
            "wind_speed_ms": data["windspeed_10m"],
        }
    except Exception as e:
        return {"status": "error", "error": str(e)}


# Example tool usage (optional test)
print(get_weather("Świątniki Górne"))
print(get_weather("Warszawa"))
# Out:
# {'status': 'success', 'city': 'Świątniki Górne', 'temperature_c': 8.8, 'wind_speed_ms': 5.2}
# {'status': 'success', 'city': 'Warszawa', 'temperature_c': 11.6, 'wind_speed_ms': 3.1}

# %%
# @title Define the Weather Agent
# Use one of the model constants defined earlier
AGENT_MODEL = MODEL_GEMINI_2_5_FLASH # Starting with Gemini

weatherAgent = Agent(
    name='weatherAgent',
    description='Weather agent for the application.',
    instruction='Get the weather for a given city.',
    tools=[get_weather],
    model=Gemini(
        model_name=AGENT_MODEL,
        retry_options=types.HttpRetryOptions(initial_delay=1, attempts=10),
    ),
)

print(f"Agent '{weatherAgent.name}' created using model '{AGENT_MODEL}'.")
# Out:
# Agent 'weatherAgent' created using model 'gemini-2.5-flash'.

# %%
# @title Setup Session Service and Runner

# --- Session Management ---
# Key Concept: SessionService stores conversation history & state.
# InMemorySessionService is simple, non-persistent storage for this tutorial.
session_service = InMemorySessionService()

# Define constants for identifying the interaction context
APP_NAME = "weather_tutorial_app"
USER_ID = "user_1"
SESSION_ID = "session_001" # Using a fixed ID for simplicity

# Create the specific session where the conversation will happen
session = await session_service.create_session(
    app_name=APP_NAME,
    user_id=USER_ID,
    session_id=SESSION_ID
)
print(f"Session created: App='{APP_NAME}', User='{USER_ID}', Session='{SESSION_ID}'")

# --- OR ---

# Uncomment the following lines if running as a standard Python script (.py file):

# async def init_session(app_name:str,user_id:str,session_id:str) -> InMemorySessionService:
#     session = await session_service.create_session(
#         app_name=app_name,
#         user_id=user_id,
#         session_id=session_id
#     )
#     print(f"Session created: App='{app_name}', User='{user_id}', Session='{session_id}'")
#     return session
# 
# session = asyncio.run(init_session(APP_NAME,USER_ID,SESSION_ID))

# --- Runner ---
# Key Concept: Runner orchestrates the agent execution loop.
runner = Runner(
    agent=weatherAgent, # The agent we want to run
    app_name=APP_NAME,   # Associates runs with our app
    session_service=session_service # Uses our session manager
)
print(f"Runner created for agent '{runner.agent.name}'.")
# Out:
# Session created: App='weather_tutorial_app', User='user_1', Session='session_001'
# Runner created for agent 'weatherAgent'.

# %%
# @title Define Agent Interaction Function

from google.genai import types # For creating message Content/Parts

async def call_agent_async(query: str, runner, user_id, session_id):
  """Sends a query to the agent and prints the final response."""
  print(f"\n>>> User Query: {query}")

  # Prepare the user's message in ADK format
  content = types.Content(role='user', parts=[types.Part(text=query)])

  final_response_text = "Agent did not produce a final response." # Default

  # Key Concept: run_async executes the agent logic and yields Events.
  # We iterate through events to find the final answer.
  async for event in runner.run_async(user_id=user_id, session_id=session_id, new_message=content):
      # You can uncomment the line below to see *all* events during execution
      # print(f"  [Event] Author: {event.author}, Type: {type(event).__name__}, Final: {event.is_final_response()}, Content: {event.content}")

      # Key Concept: is_final_response() marks the concluding message for the turn.
      if event.is_final_response():
          if event.content and event.content.parts:
             # Assuming text response in the first part
             final_response_text = event.content.parts[0].text
          elif event.actions and event.actions.escalate: # Handle potential errors/escalations
             final_response_text = f"Agent escalated: {event.error_message or 'No specific message.'}"
          # Add more checks here if needed (e.g., specific error codes)
          break # Stop processing events once the final response is found

  print(f"<<< Agent Response: {final_response_text}")

# %%
# @title Run the Initial Conversation

# We need an async function to await our interaction helper
async def run_conversation():
    await call_agent_async("What is the weather like in London?",
                                       runner=runner,
                                       user_id=USER_ID,
                                       session_id=SESSION_ID)

    await call_agent_async("How about Paris?",
                                       runner=runner,
                                       user_id=USER_ID,
                                       session_id=SESSION_ID) # Expecting the tool's error message

    await call_agent_async("Tell me the weather in New York",
                                       runner=runner,
                                       user_id=USER_ID,
                                       session_id=SESSION_ID)

# Execute the conversation using await in an async context (like Colab/Jupyter)
await run_conversation()

# --- OR ---

# Uncomment the following lines if running as a standard Python script (.py file):
# import asyncio
# if __name__ == "__main__":
#     try:
#         asyncio.run(run_conversation())
#     except Exception as e:


#         print(f"An error occurred: {e}")
# Out:
# >>> User Query: What is the weather like in London?
# <<< Agent Response: The weather in London is 11.4 degrees Celsius with a wind speed of 4.6 m/s.
#
# >>> User Query: How about Paris?
# <<< Agent Response: The weather in Paris is 12.9 degrees Celsius with a wind speed of 3.81 m/s.
#
# >>> User Query: Tell me the weather in New York
# <<< Agent Response: The weather in New York is 11.3 degrees Celsius with a wind speed of 6.02 m/s.

# %%
# @title Define and Test GPT Agent

# Make sure 'get_weather' function from Step 1 is defined in your environment.
# Make sure 'call_agent_async' is defined from earlier.

# --- Agent using GPT-4o ---
weather_agent_gpt = None # Initialize to None
runner_gpt = None      # Initialize runner to None

try:
    weather_agent_gpt = Agent(
        name="weather_agent_gpt",
        # Key change: Wrap the LiteLLM model identifier
        model=LiteLlm(model=MODEL_GPT_4O),
        description="Provides weather information (using GPT-4o).",
        instruction="You are a helpful weather assistant powered by GPT-4o. "
                    "Use the 'get_weather' tool for city weather requests. "
                    "Clearly present successful reports or polite error messages based on the tool's output status.",
        tools=[get_weather], # Re-use the same tool
    )
    print(f"Agent '{weather_agent_gpt.name}' created using model '{MODEL_GPT_4O}'.")

    # InMemorySessionService is simple, non-persistent storage for this tutorial.
    session_service_gpt = InMemorySessionService() # Create a dedicated service

    # Define constants for identifying the interaction context
    APP_NAME_GPT = "weather_tutorial_app_gpt" # Unique app name for this test
    USER_ID_GPT = "user_1_gpt"
    SESSION_ID_GPT = "session_001_gpt" # Using a fixed ID for simplicity

    # Create the specific session where the conversation will happen
    session_gpt = await session_service_gpt.create_session(
        app_name=APP_NAME_GPT,
        user_id=USER_ID_GPT,
        session_id=SESSION_ID_GPT
    )
    print(f"Session created: App='{APP_NAME_GPT}', User='{USER_ID_GPT}', Session='{SESSION_ID_GPT}'")

    # Create a runner specific to this agent and its session service
    runner_gpt = Runner(
        agent=weather_agent_gpt,
        app_name=APP_NAME_GPT,       # Use the specific app name
        session_service=session_service_gpt # Use the specific session service
        )
    print(f"Runner created for agent '{runner_gpt.agent.name}'.")

    # --- Test the GPT Agent ---
    print("\n--- Testing GPT Agent ---")
    # Ensure call_agent_async uses the correct runner, user_id, session_id
    await call_agent_async(query = "What's the weather in Tokyo?",
                           runner=runner_gpt,
                           user_id=USER_ID_GPT,
                           session_id=SESSION_ID_GPT)
    # --- OR ---

    # Uncomment the following lines if running as a standard Python script (.py file):
    # import asyncio
    # if __name__ == "__main__":
    #     try:
    #         asyncio.run(call_agent_async(query = "What's the weather in Tokyo?",
    #                      runner=runner_gpt,
    #                       user_id=USER_ID_GPT,
    
    #                       session_id=SESSION_ID_GPT)
    #     except Exception as e:
    #         print(f"An error occurred: {e}")

except Exception as e:
    print(f"❌ Could not create or run GPT agent '{MODEL_GPT_4O}'. Check API Key and model name. Error: {e}")
# Out:
# Agent 'weather_agent_gpt' created using model 'openai/gpt-4.1'.
# Session created: App='weather_tutorial_app_gpt', User='user_1_gpt', Session='session_001_gpt'
# Runner created for agent 'weather_agent_gpt'.
#
# --- Testing GPT Agent ---
#
# >>> User Query: What's the weather in Tokyo?
# <<< Agent Response: The current weather in Tokyo is 8.6°C with a wind speed of 1.24 m/s. If you'd like more details or a forecast, please let me know!

# %%
# @title Define and Test Claude Agent

# Make sure 'get_weather' function from Step 1 is defined in your environment.
# Make sure 'call_agent_async' is defined from earlier.

# --- Agent using Claude Sonnet ---
weather_agent_claude = None # Initialize to None
runner_claude = None      # Initialize runner to None

try:
    weather_agent_claude = Agent(
        name="weather_agent_claude",
        # Key change: Wrap the LiteLLM model identifier
        model=LiteLlm(model=MODEL_CLAUDE_SONNET),
        description="Provides weather information (using Claude Sonnet).",
        instruction="You are a helpful weather assistant powered by Claude Sonnet. "
                    "Use the 'get_weather' tool for city weather requests. "
                    "Analyze the tool's dictionary output ('status', 'report'/'error_message'). "
                    "Clearly present successful reports or polite error messages.",
        tools=[get_weather], # Re-use the same tool
    )
    print(f"Agent '{weather_agent_claude.name}' created using model '{MODEL_CLAUDE_SONNET}'.")

    # InMemorySessionService is simple, non-persistent storage for this tutorial.
    session_service_claude = InMemorySessionService() # Create a dedicated service

    # Define constants for identifying the interaction context
    APP_NAME_CLAUDE = "weather_tutorial_app_claude" # Unique app name
    USER_ID_CLAUDE = "user_1_claude"
    SESSION_ID_CLAUDE = "session_001_claude" # Using a fixed ID for simplicity

    # Create the specific session where the conversation will happen
    session_claude = await session_service_claude.create_session(
        app_name=APP_NAME_CLAUDE,
        user_id=USER_ID_CLAUDE,
        session_id=SESSION_ID_CLAUDE
    )
    print(f"Session created: App='{APP_NAME_CLAUDE}', User='{USER_ID_CLAUDE}', Session='{SESSION_ID_CLAUDE}'")

    # Create a runner specific to this agent and its session service
    runner_claude = Runner(
        agent=weather_agent_claude,
        app_name=APP_NAME_CLAUDE,       # Use the specific app name
        session_service=session_service_claude # Use the specific session service
        )
    print(f"Runner created for agent '{runner_claude.agent.name}'.")

    # --- Test the Claude Agent ---
    print("\n--- Testing Claude Agent ---")
    # Ensure call_agent_async uses the correct runner, user_id, session_id
    await call_agent_async(query = "Weather in London please.",
                           runner=runner_claude,
                           user_id=USER_ID_CLAUDE,
                           session_id=SESSION_ID_CLAUDE)

    # --- OR ---

    # Uncomment the following lines if running as a standard Python script (.py file):
    # import asyncio
    # if __name__ == "__main__":
    #     try:
    #         asyncio.run(call_agent_async(query = "Weather in London please.",
    #                      runner=runner_claude,
    #                       user_id=USER_ID_CLAUDE,
    #                       session_id=SESSION_ID_CLAUDE)
    #     except Exception as e:
    #         print(f"An error occurred: {e}")


except Exception as e:
    print(f"❌ Could not create or run Claude agent '{MODEL_CLAUDE_SONNET}'. Check API Key and model name. Error: {e}")
# Out:
# Agent 'weather_agent_claude' created using model 'claude-sonnet-4-6'.
# Session created: App='weather_tutorial_app_claude', User='user_1_claude', Session='session_001_claude'
# Runner created for agent 'weather_agent_claude'.
#
# --- Testing Claude Agent ---
#
# >>> User Query: Weather in London please.
# <<< Agent Response: Here's the current weather for **London**:
#
# - 🌡️ **Temperature:** 11.4°C
# - 💨 **Wind Speed:** 4.6 m/s
#
# It's a mild but breezy day in London! You might want to grab a light jacket if you're heading out. 🧥

# %%
# @title Define Tools for Greeting and Farewell Agents
from typing import Optional # Make sure to import Optional

# Ensure 'get_weather' from Step 1 is available if running this step independently.
# def get_weather(city: str) -> dict: ... (from Step 1)

def say_hello(name: Optional[str] = None) -> str:
    """Provides a simple greeting. If a name is provided, it will be used.

    Args:
        name (str, optional): The name of the person to greet. Defaults to a generic greeting if not provided.

    Returns:
        str: A friendly greeting message.
    """
    if name:
        greeting = f"Hello, {name}!"
        print(f"--- Tool: say_hello called with name: {name} ---")
    else:
        greeting = "Hello there!" # Default greeting if name is None or not explicitly passed
        print(f"--- Tool: say_hello called without a specific name (name_arg_value: {name}) ---")
    return greeting

def say_goodbye() -> str:
    """Provides a simple farewell message to conclude the conversation."""
    print(f"--- Tool: say_goodbye called ---")
    return "Goodbye! Have a great day."

print("Greeting and Farewell tools defined.")

# Optional self-test
print(say_hello("Alice"))
print(say_hello()) # Test with no argument (should use default "Hello there!")
print(say_hello(name=None)) # Test with name explicitly as None (should use default "Hello there!")
# Out:
# Greeting and Farewell tools defined.
# --- Tool: say_hello called with name: Alice ---
# Hello, Alice!
# --- Tool: say_hello called without a specific name (name_arg_value: None) ---
# Hello there!
# --- Tool: say_hello called without a specific name (name_arg_value: None) ---
# Hello there!

# %%
# @title Define Greeting and Farewell Sub-Agents

# If you want to use models other than Gemini, Ensure LiteLlm is imported and API keys are set (from Step 0/2)
# from google.adk.models.lite_llm import LiteLlm
# MODEL_GPT_4O, MODEL_CLAUDE_SONNET etc. should be defined
# Or else, continue to use: model = MODEL_GEMINI_2_5_FLASH

# --- Greeting Agent ---
greeting_agent = None
try:
    greeting_agent = Agent(
        # Using a potentially different/cheaper model for a simple task
        model = MODEL_GEMINI_2_5_FLASH,
        # model=LiteLlm(model=MODEL_GPT_4O), # If you would like to experiment with other models
        name="greeting_agent",
        instruction="You are the Greeting Agent. Your ONLY task is to provide a friendly greeting to the user. "
                    "Use the 'say_hello' tool to generate the greeting. "
                    "If the user provides their name, make sure to pass it to the tool. "
                    "Do not engage in any other conversation or tasks.",
        description="Handles simple greetings and hellos using the 'say_hello' tool.", # Crucial for delegation
        tools=[say_hello],
    )
    print(f"✅ Agent '{greeting_agent.name}' created using model '{greeting_agent.model}'.")
except Exception as e:
    print(f"❌ Could not create Greeting agent. Check API Key ({greeting_agent.model}). Error: {e}")

# --- Farewell Agent ---
farewell_agent = None
try:
    farewell_agent = Agent(
        # Can use the same or a different model
        model = MODEL_GEMINI_2_5_FLASH,
        # model=LiteLlm(model=MODEL_GPT_4O), # If you would like to experiment with other models
        name="farewell_agent",
        instruction="You are the Farewell Agent. Your ONLY task is to provide a polite goodbye message. "
                    "Use the 'say_goodbye' tool when the user indicates they are leaving or ending the conversation "
                    "(e.g., using words like 'bye', 'goodbye', 'thanks bye', 'see you'). "
                    "Do not perform any other actions.",
        description="Handles simple farewells and goodbyes using the 'say_goodbye' tool.", # Crucial for delegation
        tools=[say_goodbye],
    )
    print(f"✅ Agent '{farewell_agent.name}' created using model '{farewell_agent.model}'.")
except Exception as e:
    print(f"❌ Could not create Farewell agent. Check API Key ({farewell_agent.model}). Error: {e}")
# Out:
# ✅ Agent 'greeting_agent' created using model 'gemini-2.5-flash'.
# ✅ Agent 'farewell_agent' created using model 'gemini-2.5-flash'.

# %%
# @title Define the Root Agent with Sub-Agents

# Ensure sub-agents were created successfully before defining the root agent.
# Also ensure the original 'get_weather' tool is defined.
root_agent = None
runner_root = None # Initialize runner

if greeting_agent and farewell_agent and 'get_weather' in globals():
    # Let's use a capable Gemini model for the root agent to handle orchestration
    root_agent_model = MODEL_GEMINI_2_5_FLASH

    weather_agent_team = Agent(
        name="weather_agent_v2", # Give it a new version name
        model=root_agent_model,
        description="The main coordinator agent. Handles weather requests and delegates greetings/farewells to specialists.",
        instruction="You are the main Weather Agent coordinating a team. Your primary responsibility is to provide weather information. "
                    "Use the 'get_weather' tool ONLY for specific weather requests (e.g., 'weather in London'). "
                    "You have specialized sub-agents: "
                    "1. 'greeting_agent': Handles simple greetings like 'Hi', 'Hello'. Delegate to it for these. "
                    "2. 'farewell_agent': Handles simple farewells like 'Bye', 'See you'. Delegate to it for these. "
                    "Analyze the user's query. If it's a greeting, delegate to 'greeting_agent'. If it's a farewell, delegate to 'farewell_agent'. "
                    "If it's a weather request, handle it yourself using 'get_weather'. "
                    "For anything else, respond appropriately or state you cannot handle it.",
        tools=[get_weather], # Root agent still needs the weather tool for its core task
        # Key change: Link the sub-agents here!
        sub_agents=[greeting_agent, farewell_agent]
    )
    print(f"✅ Root Agent '{weather_agent_team.name}' created using model '{root_agent_model}' with sub-agents: {[sa.name for sa in weather_agent_team.sub_agents]}")

else:
    print("❌ Cannot create root agent because one or more sub-agents failed to initialize or 'get_weather' tool is missing.")
    if not greeting_agent: print(" - Greeting Agent is missing.")
    if not farewell_agent: print(" - Farewell Agent is missing.")
    if 'get_weather' not in globals(): print(" - get_weather function is missing.")
# Out:
# ✅ Root Agent 'weather_agent_v2' created using model 'gemini-2.5-flash' with sub-agents: ['greeting_agent', 'farewell_agent']

# %%
# @title Interact with the Agent Team
import asyncio # Ensure asyncio is imported

# Ensure the root agent (e.g., 'weather_agent_team' or 'root_agent' from the previous cell) is defined.
# Ensure the call_agent_async function is defined.

# Check if the root agent variable exists before defining the conversation function
root_agent_var_name = 'root_agent' # Default name from Step 3 guide
if 'weather_agent_team' in globals(): # Check if user used this name instead
    root_agent_var_name = 'weather_agent_team'
elif 'root_agent' not in globals():
    print("⚠️ Root agent ('root_agent' or 'weather_agent_team') not found. Cannot define run_team_conversation.")
    # Assign a dummy value to prevent NameError later if the code block runs anyway
    root_agent = None # Or set a flag to prevent execution

# Only define and run if the root agent exists
if root_agent_var_name in globals() and globals()[root_agent_var_name]:
    # Define the main async function for the conversation logic.
    # The 'await' keywords INSIDE this function are necessary for async operations.
    async def run_team_conversation():
        print("\n--- Testing Agent Team Delegation ---")
        session_service = InMemorySessionService()
        APP_NAME = "weather_tutorial_agent_team"
        USER_ID = "user_1_agent_team"
        SESSION_ID = "session_001_agent_team"
        session = await session_service.create_session(
            app_name=APP_NAME, user_id=USER_ID, session_id=SESSION_ID
        )
        print(f"Session created: App='{APP_NAME}', User='{USER_ID}', Session='{SESSION_ID}'")

        actual_root_agent = globals()[root_agent_var_name]
        runner_agent_team = Runner( # Or use InMemoryRunner
            agent=actual_root_agent,
            app_name=APP_NAME,
            session_service=session_service
        )
        print(f"Runner created for agent '{actual_root_agent.name}'.")

        # --- Interactions using await (correct within async def) ---
        await call_agent_async(query = "Hello there!",
                               runner=runner_agent_team,
                               user_id=USER_ID,
                               session_id=SESSION_ID)
        await call_agent_async(query = "What is the weather in New York?",
                               runner=runner_agent_team,
                               user_id=USER_ID,
                               session_id=SESSION_ID)
        await call_agent_async(query = "Thanks, bye!",
                               runner=runner_agent_team,
                               user_id=USER_ID,
                               session_id=SESSION_ID)

    # --- Execute the `run_team_conversation` async function ---
    # Choose ONE of the methods below based on your environment.
    # Note: This may require API keys for the models used!

    # METHOD 1: Direct await (Default for Notebooks/Async REPLs)
    # If your environment supports top-level await (like Colab/Jupyter notebooks),
    # it means an event loop is already running, so you can directly await the function.
    print("Attempting execution using 'await' (default for notebooks)...")
    await run_team_conversation()

    # METHOD 2: asyncio.run (For Standard Python Scripts [.py])
    # If running this code as a standard Python script from your terminal,
    # the script context is synchronous. `asyncio.run()` is needed to
    # create and manage an event loop to execute your async function.
    # To use this method:
    # 1. Comment out the `await run_team_conversation()` line above.
    # 2. Uncomment the following block:
    """
    import asyncio
    if __name__ == "__main__": # Ensures this runs only when script is executed directly
        print("Executing using 'asyncio.run()' (for standard Python scripts)...")
        try:
            # This creates an event loop, runs your async function, and closes the loop.
            asyncio.run(run_team_conversation())
        except Exception as e:
            print(f"An error occurred: {e}")
    """

else:
    # This message prints if the root agent variable wasn't found earlier
    print("\n⚠️ Skipping agent team conversation execution as the root agent was not successfully defined in a previous step.")
# Out:
# Attempting execution using 'await' (default for notebooks)...
#
# --- Testing Agent Team Delegation ---
# Session created: App='weather_tutorial_agent_team', User='user_1_agent_team', Session='session_001_agent_team'
# Runner created for agent 'weather_agent_v2'.
#
# >>> User Query: Hello there!
# --- Tool: say_hello called without a specific name (name_arg_value: None) ---
# <<< Agent Response: Hello there!
#
#
# >>> User Query: What is the weather in New York?
# <<< Agent Response: The current weather in New York is 11.3 degrees Celsius with a wind speed of 6.02 m/s.
#
# >>> User Query: Thanks, bye!
# --- Tool: say_goodbye called ---
# <<< Agent Response: Goodbye! Have a great day.

# %%
# @title 1. Initialize New Session Service and State

# Import necessary session components
from google.adk.sessions import InMemorySessionService

# Create a NEW session service instance for this state demonstration
session_service_stateful = InMemorySessionService()
print("✅ New InMemorySessionService created for state demonstration.")

# Define a NEW session ID for this part of the tutorial
SESSION_ID_STATEFUL = "session_state_demo_001"
USER_ID_STATEFUL = "user_state_demo"

# Define initial state data - user prefers Celsius initially
initial_state = {
    "user_preference_temperature_unit": "Celsius"
}

# Create the session, providing the initial state
session_stateful = await session_service_stateful.create_session(
    app_name=APP_NAME, # Use the consistent app name
    user_id=USER_ID_STATEFUL,
    session_id=SESSION_ID_STATEFUL,
    state=initial_state # <<< Initialize state during creation
)
print(f"✅ Session '{SESSION_ID_STATEFUL}' created for user '{USER_ID_STATEFUL}'.")

# Verify the initial state was set correctly
retrieved_session = await session_service_stateful.get_session(app_name=APP_NAME,
                                                         user_id=USER_ID_STATEFUL,
                                                         session_id = SESSION_ID_STATEFUL)
print("\n--- Initial Session State ---")
if retrieved_session:
    print(retrieved_session.state)
else:
    print("Error: Could not retrieve session.")
# Out:
# ✅ New InMemorySessionService created for state demonstration.
# ✅ Session 'session_state_demo_001' created for user 'user_state_demo'.
#
# --- Initial Session State ---
# {'user_preference_temperature_unit': 'Celsius'}

# %%
from google.adk.tools.tool_context import ToolContext

def get_weather_stateful(city: str, tool_context: ToolContext) -> dict:
    """Retrieves weather, converts temp unit based on session state."""
    print(f"--- Tool: get_weather_stateful called for {city} ---")

    # --- Read preference from state ---
    preferred_unit = tool_context.state.get("user_preference_temperature_unit", "Celsius") # Default to Celsius
    print(f"--- Tool: Reading state 'user_preference_temperature_unit': {preferred_unit} ---")

    city_normalized = city.lower().replace(" ", "")

    # Mock weather data (always stored in Celsius internally)
    mock_weather_db = {
        "newyork": {"temp_c": 25, "condition": "sunny"},
        "london": {"temp_c": 15, "condition": "cloudy"},
        "tokyo": {"temp_c": 18, "condition": "light rain"},
    }

    if city_normalized in mock_weather_db:
        data = mock_weather_db[city_normalized]
        temp_c = data["temp_c"]
        condition = data["condition"]

        # Format temperature based on state preference
        if preferred_unit == "Fahrenheit":
            temp_value = (temp_c * 9/5) + 32 # Calculate Fahrenheit
            temp_unit = "°F"
        else: # Default to Celsius
            temp_value = temp_c
            temp_unit = "°C"

        report = f"The weather in {city.capitalize()} is {condition} with a temperature of {temp_value:.0f}{temp_unit}."
        result = {"status": "success", "report": report}
        print(f"--- Tool: Generated report in {preferred_unit}. Result: {result} ---")

        # Example of writing back to state (optional for this tool)
        tool_context.state["last_city_checked_stateful"] = city
        print(f"--- Tool: Updated state 'last_city_checked_stateful': {city} ---")

        return result
    else:
        # Handle city not found
        error_msg = f"Sorry, I don't have weather information for '{city}'."
        print(f"--- Tool: City '{city}' not found. ---")
        return {"status": "error", "error_message": error_msg}

print("✅ State-aware 'get_weather_stateful' tool defined.")
# Out:
# ✅ State-aware 'get_weather_stateful' tool defined.

# %%
# @title 3. Redefine Sub-Agents and Update Root Agent with output_key

# Ensure necessary imports: Agent, LiteLlm, Runner
from google.adk.agents import Agent
from google.adk.models.lite_llm import LiteLlm
from google.adk.runners import Runner
# Ensure tools 'say_hello', 'say_goodbye' are defined (from Step 3)
# Ensure model constants MODEL_GPT_4O, MODEL_GEMINI_2_5_FLASH etc. are defined

# --- Redefine Greeting Agent (from Step 3) ---
greeting_agent = None
try:
    greeting_agent = Agent(
        model=MODEL_GEMINI_2_5_FLASH,
        name="greeting_agent",
        instruction="You are the Greeting Agent. Your ONLY task is to provide a friendly greeting using the 'say_hello' tool. Do nothing else.",
        description="Handles simple greetings and hellos using the 'say_hello' tool.",
        tools=[say_hello],
        output_key="last_greeting" # <<< Auto-save agent's final weather response
    )
    print(f"✅ Agent '{greeting_agent.name}' redefined.")
except Exception as e:
    print(f"❌ Could not redefine Greeting agent. Error: {e}")

# --- Redefine Farewell Agent (from Step 3) ---
farewell_agent = None
try:
    farewell_agent = Agent(
        model=MODEL_GEMINI_2_5_FLASH,
        name="farewell_agent",
        instruction="You are the Farewell Agent. Your ONLY task is to provide a polite goodbye message using the 'say_goodbye' tool. Do not perform any other actions.",
        description="Handles simple farewells and goodbyes using the 'say_goodbye' tool.",
        tools=[say_goodbye],
    )
    print(f"✅ Agent '{farewell_agent.name}' redefined.")
except Exception as e:
    print(f"❌ Could not redefine Farewell agent. Error: {e}")

# --- Define the Updated Root Agent ---
root_agent_stateful = None
runner_root_stateful = None # Initialize runner

# Check prerequisites before creating the root agent
if greeting_agent and farewell_agent and 'get_weather_stateful' in globals():

    root_agent_model = MODEL_GEMINI_2_5_FLASH # Choose orchestration model

    root_agent_stateful = Agent(
        name="weather_agent_v4_stateful", # New version name
        model=root_agent_model,
        description="Main agent: Provides weather (state-aware unit), delegates greetings/farewells, saves report to state.",
        instruction="You are the main Weather Agent. Your job is to provide weather using 'get_weather_stateful'. "
                    "The tool will format the temperature based on user preference stored in state. "
                    "Delegate simple greetings to 'greeting_agent' and farewells to 'farewell_agent'. "
                    "Handle only weather requests, greetings, and farewells.",
        tools=[get_weather_stateful], # Use the state-aware tool
        sub_agents=[greeting_agent, farewell_agent], # Include sub-agents
        output_key="last_weather_report" # <<< Auto-save agent's final weather response
    )
    print(f"✅ Root Agent '{root_agent_stateful.name}' created using stateful tool and output_key.")

    # --- Create Runner for this Root Agent & NEW Session Service ---
    runner_root_stateful = Runner(
        agent=root_agent_stateful,
        app_name=APP_NAME,
        session_service=session_service_stateful # Use the NEW stateful session service
    )
    print(f"✅ Runner created for stateful root agent '{runner_root_stateful.agent.name}' using stateful session service.")

else:
    print("❌ Cannot create stateful root agent. Prerequisites missing.")
    if not greeting_agent: print(" - greeting_agent definition missing.")
    if not farewell_agent: print(" - farewell_agent definition missing.")
    if 'get_weather_stateful' not in globals(): print(" - get_weather_stateful tool missing.")
# Out:
# ✅ Agent 'greeting_agent' redefined.
# ✅ Agent 'farewell_agent' redefined.
# ✅ Root Agent 'weather_agent_v4_stateful' created using stateful tool and output_key.
# ✅ Runner created for stateful root agent 'weather_agent_v4_stateful' using stateful session service.

# %%
# @title 4. Interact to Test State Flow and output_key
import asyncio # Ensure asyncio is imported

# Ensure the stateful runner (runner_root_stateful) is available from the previous cell
# Ensure call_agent_async, USER_ID_STATEFUL, SESSION_ID_STATEFUL, APP_NAME are defined

if 'runner_root_stateful' in globals() and runner_root_stateful:
    # Define the main async function for the stateful conversation logic.
    # The 'await' keywords INSIDE this function are necessary for async operations.
    async def run_stateful_conversation():
        print("\n--- Testing State: Temp Unit Conversion & output_key ---")

        # 0. Test basic delegation (greeting)
        # This will update 'last_greeting' in state via output_key
        print("\n--- Turn 0: Sending a greeting ---")
        await call_agent_async(query= "Hi! I'm John.",
                               runner=runner_root_stateful,
                               user_id=USER_ID_STATEFUL,
                               session_id=SESSION_ID_STATEFUL
                              )
        
        # 1. Check weather (Uses initial state: Celsius)
        print("--- Turn 1: Requesting weather in London (expect Celsius) ---")
        await call_agent_async(query= "What's the weather in London?",
                               runner=runner_root_stateful,
                               user_id=USER_ID_STATEFUL,
                               session_id=SESSION_ID_STATEFUL
                              )

        # 2. Manually update state preference to Fahrenheit - DIRECTLY MODIFY STORAGE
        print("\n--- Manually Updating State: Setting unit to Fahrenheit ---")
        try:
            # Access the internal storage directly - THIS IS SPECIFIC TO InMemorySessionService for testing
            # NOTE: In production with persistent services (Database, VertexAI), you would
            # typically update state via agent actions or specific service APIs if available,
            # not by direct manipulation of internal storage.
            stored_session = session_service_stateful.sessions[APP_NAME][USER_ID_STATEFUL][SESSION_ID_STATEFUL]
            stored_session.state["user_preference_temperature_unit"] = "Fahrenheit"
            # Optional: You might want to update the timestamp as well if any logic depends on it
            # import time
            # stored_session.last_update_time = time.time()
            print(f"--- Stored session state updated. Current 'user_preference_temperature_unit': {stored_session.state.get('user_preference_temperature_unit', 'Not Set')} ---") # Added .get for safety
        except KeyError:
            print(f"--- Error: Could not retrieve session '{SESSION_ID_STATEFUL}' from internal storage for user '{USER_ID_STATEFUL}' in app '{APP_NAME}' to update state. Check IDs and if session was created. ---")
        except Exception as e:
             print(f"--- Error updating internal session state: {e} ---")

        # 3. Check weather again (Tool should now use Fahrenheit)
        # This will also update 'last_weather_report' via output_key
        print("\n--- Turn 2: Requesting weather in New York (expect Fahrenheit) ---")
        await call_agent_async(query= "Tell me the weather in New York.",
                               runner=runner_root_stateful,
                               user_id=USER_ID_STATEFUL,
                               session_id=SESSION_ID_STATEFUL
                              )

        # 4. Test basic delegation (should still work)
        # This will update 'last_weather_report' again, overwriting the NY weather report
        print("\n--- Turn 3: Sending a greeting ---")
        await call_agent_async(query= "Hi! I'm Kate",
                               runner=runner_root_stateful,
                               user_id=USER_ID_STATEFUL,
                               session_id=SESSION_ID_STATEFUL
                              )

    # --- Execute the `run_stateful_conversation` async function ---
    # Choose ONE of the methods below based on your environment.

    # METHOD 1: Direct await (Default for Notebooks/Async REPLs)
    # If your environment supports top-level await (like Colab/Jupyter notebooks),
    # it means an event loop is already running, so you can directly await the function.
    print("Attempting execution using 'await' (default for notebooks)...")
    await run_stateful_conversation()

    # METHOD 2: asyncio.run (For Standard Python Scripts [.py])
    # If running this code as a standard Python script from your terminal,
    # the script context is synchronous. `asyncio.run()` is needed to
    # create and manage an event loop to execute your async function.
    # To use this method:
    # 1. Comment out the `await run_stateful_conversation()` line above.
    # 2. Uncomment the following block:
    """
    import asyncio
    if __name__ == "__main__": # Ensures this runs only when script is executed directly
        print("Executing using 'asyncio.run()' (for standard Python scripts)...")
        try:
            # This creates an event loop, runs your async function, and closes the loop.
            asyncio.run(run_stateful_conversation())
        except Exception as e:
            print(f"An error occurred: {e}")
    """

    # --- Inspect final session state after the conversation ---
    # This block runs after either execution method completes.
    print("\n--- Inspecting Final Session State ---")
    final_session = await session_service_stateful.get_session(app_name=APP_NAME,
                                                         user_id= USER_ID_STATEFUL,
                                                         session_id=SESSION_ID_STATEFUL)
    if final_session:
        # Use .get() for safer access to potentially missing keys
        print(f"Final Preference: {final_session.state.get('user_preference_temperature_unit', 'Not Set')}")
        print(f"Final Last Weather Report (from output_key): {final_session.state.get('last_weather_report', 'Not Set')}")
        print(f"Final Last Greeting (from output_key): {final_session.state.get('last_greeting', 'Not Set')}")
        print(f"Final Last City Checked (by tool): {final_session.state.get('last_city_checked_stateful', 'Not Set')}")
        # Print full state for detailed view
        # print(f"Full State Dict: {final_session.state}") # For detailed view
    else:
        print("\n❌ Error: Could not retrieve final session state.")

else:
    print("\n⚠️ Skipping state test conversation. Stateful root agent runner ('runner_root_stateful') is not available.")
# Out:
# Attempting execution using 'await' (default for notebooks)...
#
# --- Testing State: Temp Unit Conversion & output_key ---
#
# --- Turn 0: Sending a greeting ---
#
# >>> User Query: Hi!
# --- Tool: say_hello called without a specific name (name_arg_value: None) ---
# <<< Agent Response: Hello there!
# --- Turn 1: Requesting weather in London (expect Celsius) ---
#
# >>> User Query: What's the weather in London?
# --- Tool: get_weather_stateful called for London ---
# --- Tool: Reading state 'user_preference_temperature_unit': Fahrenheit ---
# --- Tool: Generated report in Fahrenheit. Result: {'status': 'success', 'report': 'The weather in London is cloudy with a temperature of 59°F.'} ---
# --- Tool: Updated state 'last_city_checked_stateful': London ---
# <<< Agent Response: The weather in London is cloudy with a temperature of 59°F.
#
# --- Manually Updating State: Setting unit to Fahrenheit ---
# --- Stored session state updated. Current 'user_preference_temperature_unit': Fahrenheit ---
#
# --- Turn 2: Requesting weather in New York (expect Fahrenheit) ---
#
# >>> User Query: Tell me the weather in New York.
# --- Tool: get_weather_stateful called for New York ---
# --- Tool: Reading state 'user_preference_temperature_unit': Fahrenheit ---
# --- Tool: Generated report in Fahrenheit. Result: {'status': 'success', 'report': 'The weather in New york is sunny with a temperature of 77°F.'} ---
# --- Tool: Updated state 'last_city_checked_stateful': New York ---
# <<< Agent Response: The weather in New York is sunny with a temperature of 77°F.
#
# --- Turn 3: Sending a greeting ---
#
# >>> User Query: Hi!
# --- Tool: say_hello called without a specific name (name_arg_value: None) ---
# <<< Agent Response: Hello there!
#
# --- Inspecting Final Session State ---
# Final Preference: Fahrenheit
# Final Last Weather Report (from output_key): The weather in New York is sunny with a temperature of 77°F.
# Final Last Greeting (from output_key): Hello there!
# Final Last City Checked (by tool): New York
